# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import StandardScaler

# %%
X, y = fetch_california_housing(return_X_y=True,as_frame=True)

# %%
X.describe().round(2)
# Out:
#          MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# count  20640.00  20640.00  20640.00   20640.00    20640.00  20640.00
# mean       3.87     28.64      5.43       1.10     1425.48      3.07
# std        1.90     12.59      2.47       0.47     1132.46     10.39
# min        0.50      1.00      0.85       0.33        3.00      0.69
# 25%        2.56     18.00      4.44       1.01      787.00      2.43
# 50%        3.53     29.00      5.23       1.05     1166.00      2.82
# 75%        4.74     37.00      6.05       1.10     1725.00      3.28
# max       15.00     52.00    141.91      34.07    35682.00   1243.33
#
#        Latitude  Longitude
# count  20640.00   20640.00
# mean      35.63    -119.57
# std        2.14       2.00
# min       32.54    -124.35
# 25%       33.93    -121.80
# 50%       34.26    -118.49
# 75%       37.71    -118.01
# max       41.95    -114.31

# %%
X_train, X_test ,y_train , y_test = train_test_split(
    X,
    y,
    
    test_size=0.3,
    random_state=0,
    )

X_train.head()
# Out:
#       MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 1989  1.9750      52.0  2.800000   0.700000       193.0  4.825000     36.73
# 256   2.2604      43.0  3.671480   1.184116       836.0  3.018051     37.77
# 7887  6.2990      17.0  6.478022   1.087912      1387.0  3.810440     33.87
# 4581  1.7199      17.0  2.518000   1.196000      3051.0  3.051000     34.06
# 1993  2.2206      50.0  4.622754   1.161677       606.0  3.628743     36.73
#
#       Longitude
# 1989    -119.79
# 256     -122.21
# 7887    -118.04
# 4581    -118.28
# 1993    -119.81

# %%
scaler = StandardScaler().set_output(transform="pandas")

scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled  = scaler.transform(X_test)

# %%
X_train_scaled
X_test_scaled
# Out:
#          MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# 14740  0.150777 -0.525450  0.104772  -0.042637    0.109472  0.166000
# 10101  1.011549  0.268437  0.298934  -0.368947   -0.112356 -0.002845
# 20566  0.254896  0.030271  0.221770  -0.151429    0.112082 -0.018988
# 2670  -0.748545  0.665380 -0.188170   0.490631   -0.900497 -0.042813
# 15709  0.601892 -0.287284 -0.482677  -0.121919   -0.675189 -0.193380
# ...         ...       ...       ...        ...         ...       ...
# 19681 -0.407419  0.585991 -0.295943  -0.362914   -0.223704 -0.094930
# 12156  0.143797 -2.113223  1.485356   0.706824    1.218611  0.047726
# 10211  2.119586  0.109659  0.930048  -0.250241   -0.784798 -0.090161
# 2445  -0.952290  0.427214  0.225019   0.246083   -0.923984  0.102178
# 17914  0.428024  0.268437 -0.047323  -0.249498   -0.442053 -0.038109
#
#        Latitude  Longitude
# 14740 -1.425246   1.254236
# 10101 -0.799092   0.795730
# 20566  1.411141  -1.132985
# 2670  -1.135533   1.976881
# 15709  1.009280  -1.427027
# ...         ...        ...
# 19681  1.644780  -1.023342
# 12156 -0.920584   1.194431
# 10211 -0.813110   0.825633
# 2445   0.434526  -0.036558
# 17914  0.808350  -1.207741
#
# [6192 rows x 8 columns]

# %%
scaler.mean_
# Out:
# array([ 3.86666741e+00,  2.86187016e+01,  5.42340368e+00,  1.09477484e+00,
#         1.42515732e+03,  3.04051776e+00,  3.56300934e+01, -1.19566647e+02])

# %%
X_train.hist(bins=20, figsize=(10,10))
plt.show()

# %%
X_train_scaled.hist(bins=20, figsize=(10,10))
plt.show()
