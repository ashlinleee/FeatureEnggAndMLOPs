# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import MinMaxScaler

# %%
X,y = fetch_california_housing(return_X_y=True,as_frame=True)

# %%
X.describe().round(2)
# Out:
#          MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# count  20640.00  20640.00  20640.00   20640.00    20640.00  20640.00
# mean       3.87     28.64      5.43       1.10     1425.48      3.07
# std        1.90     12.59      2.47       0.47     1132.46     10.39
# min        0.50      1.00      0.85       0.33        3.00      0.69
# 25%        2.56     18.00      4.44       1.01      787.00      2.43
# 50%        3.53     29.00      5.23       1.05     1166.00      2.82
# 75%        4.74     37.00      6.05       1.10     1725.00      3.28
# max       15.00     52.00    141.91      34.07    35682.00   1243.33
#
#        Latitude  Longitude
# count  20640.00   20640.00
# mean      35.63    -119.57
# std        2.14       2.00
# min       32.54    -124.35
# 25%       33.93    -121.80
# 50%       34.26    -118.49
# 75%       37.71    -118.01
# max       41.95    -114.31

# %%
X_train, X_test ,y_train , y_test = train_test_split(
    X,
    y,
    
    test_size=0.3,
    random_state=0,
    )

X_train.head()
# Out:
#       MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 1989  1.9750      52.0  2.800000   0.700000       193.0  4.825000     36.73
# 256   2.2604      43.0  3.671480   1.184116       836.0  3.018051     37.77
# 7887  6.2990      17.0  6.478022   1.087912      1387.0  3.810440     33.87
# 4581  1.7199      17.0  2.518000   1.196000      3051.0  3.051000     34.06
# 1993  2.2206      50.0  4.622754   1.161677       606.0  3.628743     36.73
#
#       Longitude
# 1989    -119.79
# 256     -122.21
# 7887    -118.04
# 4581    -118.28
# 1993    -119.81

# %%
scaler = MinMaxScaler().set_output(transform="pandas")

scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled  = scaler.transform(X_test)

# %%
X_train_scaled
X_test_scaled
# Out:
#          MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# 14740  0.251852  0.411765  0.036578   0.022000    0.043387  0.005728
# 10101  0.364112  0.607843  0.039951   0.017621    0.036240  0.003792
# 20566  0.265431  0.549020  0.038611   0.020540    0.043471  0.003606
# 2670   0.134564  0.705882  0.031490   0.029157    0.010847  0.003333
# 15709  0.310685  0.470588  0.026374   0.020936    0.018106  0.001607
# ...         ...       ...       ...        ...         ...       ...
# 19681  0.179053  0.686275  0.029618   0.017702    0.032652  0.002736
# 12156  0.250941  0.019608  0.060561   0.032059    0.079122  0.004371
# 10211  0.508621  0.568627  0.050914   0.019214    0.014574  0.002790
# 2445   0.107992  0.647059  0.038667   0.025875    0.010090  0.004996
# 17914  0.288010  0.607843  0.033936   0.019224    0.025617  0.003387
#
#        Latitude  Longitude
# 14740  0.004251   0.727092
# 10101  0.146652   0.635458
# 20566  0.649309   0.250000
# 2670   0.070138   0.871514
# 15709  0.557917   0.191235
# ...         ...        ...
# 19681  0.702444   0.271912
# 12156  0.119022   0.715139
# 10211  0.143464   0.641434
# 2445   0.427205   0.469124
# 17914  0.512221   0.235060
#
# [6192 rows x 8 columns]

# %%
X_train.hist(bins=20, figsize=(10,10))
plt.show()
