# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import RobustScaler

# %%
X, y = fetch_california_housing(return_X_y=True,as_frame=True)

# %%
X.describe().round(2)
# Out:
#          MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# count  20640.00  20640.00  20640.00   20640.00    20640.00  20640.00
# mean       3.87     28.64      5.43       1.10     1425.48      3.07
# std        1.90     12.59      2.47       0.47     1132.46     10.39
# min        0.50      1.00      0.85       0.33        3.00      0.69
# 25%        2.56     18.00      4.44       1.01      787.00      2.43
# 50%        3.53     29.00      5.23       1.05     1166.00      2.82
# 75%        4.74     37.00      6.05       1.10     1725.00      3.28
# max       15.00     52.00    141.91      34.07    35682.00   1243.33
#
#        Latitude  Longitude
# count  20640.00   20640.00
# mean      35.63    -119.57
# std        2.14       2.00
# min       32.54    -124.35
# 25%       33.93    -121.80
# 50%       34.26    -118.49
# 75%       37.71    -118.01
# max       41.95    -114.31

# %%
X_train, X_test ,y_train , y_test = train_test_split(
    X,
    y,
    
    test_size=0.3,
    random_state=0,
    )

X_train.head()
# Out:
#       MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 1989  1.9750      52.0  2.800000   0.700000       193.0  4.825000     36.73
# 256   2.2604      43.0  3.671480   1.184116       836.0  3.018051     37.77
# 7887  6.2990      17.0  6.478022   1.087912      1387.0  3.810440     33.87
# 4581  1.7199      17.0  2.518000   1.196000      3051.0  3.051000     34.06
# 1993  2.2206      50.0  4.622754   1.161677       606.0  3.628743     36.73
#
#       Longitude
# 1989    -119.79
# 256     -122.21
# 7887    -118.04
# 4581    -118.28
# 1993    -119.81

# %%
scaler = RobustScaler().set_output(transform="pandas")

scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled  = scaler.transform(X_test)

# %%
X_train_scaled
X_test_scaled
# Out:
#          MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# 14740  0.282937 -0.368421  0.271884   0.283562    0.410638  1.599010
# 10101  1.034634  0.157895  0.550285  -1.285919    0.139362  0.239838
# 20566  0.373863  0.000000  0.439643  -0.239707    0.413830  0.109892
# 2670  -0.502424  0.421053 -0.148154   2.848458   -0.824468 -0.081901
# 15709  0.676888 -0.210526 -0.570436  -0.097767   -0.548936 -1.293933
# ...         ...       ...       ...        ...         ...       ...
# 19681 -0.204526  0.368421 -0.302686  -1.256901    0.003191 -0.501428
# 12156  0.276841 -1.421053  2.251451   3.888294    1.767021  0.646924
# 10211  2.002263  0.052632  1.455216  -0.714970   -0.682979 -0.463044
# 2445  -0.680351  0.263158  0.444302   1.672237   -0.853191  1.085253
# 17914  0.525052  0.157895  0.053802  -0.711393   -0.263830 -0.044032
#
#        Latitude  Longitude
# 14740 -0.444444   0.378947
# 10101 -0.089947   0.136842
# 20566  1.161376  -0.881579
# 2670  -0.280423   0.760526
# 15709  0.933862  -1.036842
# ...         ...        ...
# 19681  1.293651  -0.823684
# 12156 -0.158730   0.347368
# 10211 -0.097884   0.152632
# 2445   0.608466  -0.302632
# 17914  0.820106  -0.921053
#
# [6192 rows x 8 columns]

# %%
X_train.hist(bins=20, figsize=(10,10))
plt.show()
